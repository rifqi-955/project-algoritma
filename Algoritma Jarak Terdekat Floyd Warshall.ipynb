# %% [markdown]
# Algoritma Floyd-Warshall

# %%
"""
Pseudocode:

algorithm FloydWarshall(W):
    n = number of vertices
    dist = array[1..n][1..n] initialized to W

    for k from 1 to n:
        for i from 1 to n:
            for j from 1 to n:
                if dist[i][j] > dist[i][k] + dist[k][j]:
                    dist[i][j] = dist[i][k] + dist[k][j]
    return dist


"""

# %%
def algoritma_floydWarshall(w):
  n = len(w)
  dist = [list(baris) for baris in w]

  for k in range(n):
    for i in range(n):
      for j in range(n):
        if dist[i][j] > dist[i][k] + dist[k][j]:
          dist[i][j] = dist[i][k] + dist[k][j]

  return dist

INF = float("inf")

data_matrix = [
  [0, 5, INF, 10],
  [INF, 0, 3, INF],
  [INF, INF, 0, 1],
  [INF, INF, INF, 0]
]

hasil = algoritma_floydWarshall(data_matrix)

print("Jarak terpendek: ")
for baris in hasil:
  print(baris)
# Out:
# Jarak terpendek:
# [[0, 5, 8, 9], [inf, 0, 3, 4], [inf, inf, 0, 1], [inf, inf, inf, 0]]
# [[0, 5, 8, 9], [inf, 0, 3, 4], [inf, inf, 0, 1], [inf, inf, inf, 0]]
# [[0, 5, 8, 9], [inf, 0, 3, 4], [inf, inf, 0, 1], [inf, inf, inf, 0]]
# [[0, 5, 8, 9], [inf, 0, 3, 4], [inf, inf, 0, 1], [inf, inf, inf, 0]]

# %% [markdown]
# Komplesitas waktu O(n**3) dikarenakan terdapat 3 nested loop didalam algoritma
